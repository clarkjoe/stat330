# %%
import urllib.request as req
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import statsmodels.formula.api as smf #fitting regression model
import seaborn as sns #data visualization

# %%
weight = []
mpg = []
for line in req.urlopen('https://mheaton.byu.edu/Courses/Stat330/InClassAnalyses/1%20-%20CarMPG/Data/MPGData.txt'):
    str = line.decode('utf-8')
    weight.append(str.split(' ')[0])
    mpg.append(str.split(' ')[1].replace('\n', ''))

# %%
df = pd.DataFrame.from_dict({weight[0]: weight[1:], mpg[0]: mpg[1:]})
df['Weight'] = pd.to_numeric(df['Weight'])
df['MPG'] = pd.to_numeric(df['MPG'])

# %%
sns.regplot(x='Weight', y='MPG', data=df, color='red', lowess=True)

# %%
mylm = smf.ols(formula='MPG∼Weight', data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-6-9b170af8f3ee> in <module>
# ----> 1 mylm = smf.ols(formula='y∼x', data=df).fit()
#
# ~/.pyenv/versions/3.6.9/lib/python3.6/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     157
#     158         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 159                                   missing=missing)
#     160         ((endog, exog), missing_idx, design_info) = tmp
#     161
#
# ~/.pyenv/versions/3.6.9/lib/python3.6/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
# ...
